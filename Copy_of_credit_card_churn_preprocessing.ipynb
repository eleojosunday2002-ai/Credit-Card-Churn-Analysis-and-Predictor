# %%
import pandas as pd

# !git clone https://github.com/eleojosunday2002-ai/credit-card-churn-analysis-and-predictor.git
# Out:
# Cloning into 'credit-card-churn-analysis-and-predictor'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 39 (delta 14), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 1.42 MiB | 11.79 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# %cd credit-card-churn-analysis-and-predictor
# Out:
# /content/credit-card-churn-analysis-and-predictor/credit-card-churn-analysis-and-predictor/credit-card-churn-analysis-and-predictor

# %%
# !git branch
# Out:
# * main

# %%
# !git checkout -b favour-scaling-preprocessing
# Out:
# Switched to a new branch 'favour-scaling-preprocessing'

# %%
# !git branch
# Out:
# * favour-scaling-preprocessing
#   main

# %%
# !git checkout -b favour-scaling-preprocessing
# Out:
# fatal: a branch named 'favour-scaling-preprocessing' already exists

# %%
# !git fetch origin

# %%
# !git status
# Out:
# On branch favour-scaling-preprocessing
# nothing to commit, working tree clean

# %%
# !git status
